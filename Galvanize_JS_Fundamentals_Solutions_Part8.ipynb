// %% [markdown]
// # Solutions to JavaScript Fundamentals Course by Galvanize (Part 8)

// %% [markdown]
// Part 8 concepts:
// * jQuery
// * JSON
// * AJAX, Postman, and Google API

// %% [markdown]
// ## 65. jQuery
//
// ### a. Define jQuery
// Define jQuery in one sentence.
//
// jQuery is an open source JavaScript library.
//
// ### b. Using jQuery in your site
// Explain two ways that jQuery can be connected to a HTML web page.
//
// One way is local installation and the other way is to link through the Content Discovery Network.
//
// ### c. Using the above jQuery syntax, answer the following:
// What is the $?
//
// It is used to define or access the JQuery.
//
// ### d. Using the above jQuery syntax, answer the following:
// What is the selector?
//
// It is used to find the HTML elements.
//
// ### e. Using the above jQuery syntax, answer the following:
// Name a possible method that can be used in place of the fictional `.actionHere()`?
//
// `.hide()`
//
// ### f. Explain how to jQuery can be used with basic interaction with:
// `.ready()`
//
// This method is a useful to allow the HTML document to fully load before running any jQuery code. If methods are run before the document is fully loaded, errors can occur.
//
// ### g. Explain how to jQuery can be used with basic interaction with:
// `.click()`
//
// When a user clicks onto the selected element (this can be a button, link, or even a paragraph), the action of the method will be applied. It helps to place the .click() method within the .ready() method to make sure the document is fully loaded before the user is allowed to click on anything.

// %% [markdown]
// <div class="alert alert-block alert-info">
//   <b>Author's Note:</b>
//     It seems that I forgot to put the jQuery code in my older notes, which only includes some answers.
//   </div>

// %% [markdown]
// ## 66. jQuery Project 1
//
// Fork and clone the following Repo: https://github.com/galvanizejs/prep-week6-project1
//
// Submit the github repo containing your work jQuery below.

// %%
//HTML

<main>
  <img src="https://images.unsplash.com/photo-1499334758287-dc8133b315e9?auto=format&fit=crop&w=750&q=80&ixid=dW5zcGxhc2guY29tOzs7Ozs%3D" />
  <h1>Back to Ducking</h1>
  <a href="https://unsplash.com/photos/59yg_LpcvzQ">photo link</a> 
</main>

//CSS

body {
  background-color: #000000;
}

main {
  background-color: #ffffff;
  border: 3px solid #FFD700;
  width: 500px;
  margin: auto;
}

// %% [markdown]
// ## 67. More jQuery
//
// ### Explain how to get and set HTML elements with the following jQuery method:
// `.html()`
//
// Get: `$(selector).html()`
//
// Set: `$(selector).html(content)`
//
// ### Explain how to get and set HTML elements with the following jQuery method:
// `.text()`
//
// Get: `$(selector).text()`
//
// Set: `$(selector).text(content)`
//
// ### Explain how to get and set HTML elements with the following jQuery method:
// `.val()`
//
// It also can be used to set or return a value the same way that both the html() and text() methods do.
//
// ### Append, clone and remove HTML elements.
// Explain how to use jQuery to append, clone, and remove HTML elements.
//
// `$(selector).append()`
//
// `$(selector).append($(selector).clone())`
//
// `$(selector).remove()`
//
// ### jQuery Each Method
// Explain how jQuery's `each()` method to loop.
//
// You would write a `$(selector).action()` in between the `.each()` method.

// %% [markdown]
// ## 68. jQuery Project 2
// Submit the github repo containing your work jQuery below.

// %%
//HTML

<title>jQuerying</title>
<link rel="stylesheet" type="text/css" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css">
<link rel="stylesheet" type="text/css" href="style.css">

<body>

<h1 class="center">jQuery Mania</h1>

<main>
  <p>Have some fun applying jQuery to be interactive with the problems on this page.</p>
  <p>&nbsp;</p>
  
  
  <p>1. When this button below is clicked, call an alert box using jQuery that says, &quot;jQuery seems easy so far!&quot;. </p>
  <button class="alertme">Call Alert</button>
  <hr>
  
  
  <p>2. When this button below is clicked, change the text on the button to say &quot;I was clicked&quot;. </p>
  <button class="clickme">Click Me</button>
  <hr>
  
  
  <p>3. When this button below is clicked, add the pre-made CSS class style called 'buttonStyle' to it every button on this page.</p>
  <button class="addStyle">Click Me</button>
  <hr>
  
  
  <p>4. When this button below is clicked, add the pre-made CSS class style called 'addUniqueStyle' to only  the following button and not any of the other buttons. Hint: You'll need to use dot notion to target this unique button and it's class. </p>
  <button class="addDifferentStyle">Click Me</button>
  <hr>
  
  
  <p>5. Remove the classes on all of the buttons (both .addStyle and .addDifferentStyle)</p>
  <button class="removeBtn">Click Me</button>
  <hr>
  
  
  <p>6. By clicking the button, toggle (add and remove) the class buttonStyle on only this button.</p>
  <button class="clickToggle">Click Me</button>
  <hr>
  
  <p>7. Hide the square when the button is clicked.</p>
  <button class="squareBtn">Hide the Square</button>
  <div class="square"></div>
  <hr>
  
  <p>8. Hide the circle when it is clicked.</p>
  <div class="circle"></div>
  <hr>
  
  <p>9. Toggle the red square when the button is clicked and animate it in and out over 1.5 seconds.</p>
  <button class="toggleRedSquare">Toggle the red square</button>
  <div class="redSquare"></div>
</main>


</body>

//CSS
@import url(https://fonts.googleapis.com/css?family=Special+Elite);

body {
   font-size: 180%;	
}

main {
  width: 500px;
  margin: auto;	
  padding: 40px 0 100px 0;
}

footer {
   height: 100px;
   background-color: #000;	
}

h1 {
    color: #fff;
    font-family: 'Special Elite', cursive;
    font-size: 60px;
    padding: 60px 0;
    margin: 0;
    background-color: #000;
}

.center, 
button {
  text-align: center;
  margin:auto;
  display:block;
  margin-bottom: 20px;
}

.buttonStyle {
  border-radius: 13px;
  font-family: Arial;
  color: #fff;
  font-size: 30px;
  background: #3498db;
  padding: 10px 20px 10px 20px;
  text-decoration: none;
}

.buttonStyle:hover {
  background: #3cb0fd;
}


.addUniqueStyle {
  border-radius: 15px;
  font-family: Times;
  color: #fff;
  font-size: 25px;
  background: #fc6221;
  padding: 5px 10px;
  text-decoration: none;
}

.addUniqueStyle:hover {
  background: #3cb0fd;
}

.buttonStyle:focus,
.addUniqueStyle:focus {outline:0;}

.square {
  width: 100px;
  height: 100px;
  background-color: #FF6103;
  margin-left: 100px;
  margin:auto;
  display:block;
}


.redSquare {
  width: 100px;
  height: 100px;
  background-color: red;
  margin-left: 100px;
  margin:auto;
  display:block;
}

.circle {
  width: 100px;
  height: 100px;
  border-radius: 50%;
  background-color: #FF6103;
  margin-left: 100px;
  margin:auto;
  display:block;
}



hr {
 margin: 80px 0;   
}

//JQUERY
/*
=======================================================
** Week 4 - Project 2**
*** jQuery Mania ***
=======================================================
*/

// Add your JS here.


$(document).ready(function() {  
    
    
//1. 

$(".alertme").click(function() {
    alert("jQuery seems easy so far!");
  });
   
   
//2.  

$(".clickme").click(function() {
    $(".clickme").text("I was clicked");
  });
    
    
//3. 

$(".addStyle").click(function() {
    $("button").addClass('buttonStyle');
  });
   
    
//4.


$(".addDifferentStyle").click(function() {
    $(".addDifferentStyle").addClass('addUniqueStyle');
  });
   
 
   
//5. 

$(".removeBtn").click(function() {
    $("button").removeClass('buttonStyle');
    $("button").removeClass('addUniqueStyle');
  });

//6.

$(".clickToggle").click(function() {
    $(".clickToggle").toggleClass('buttonStyle');
  });


//7.

    $(".squareBtn").click(function() {
    $(".square").hide();
  });

//8.

$(".circle").click(function() {
    $(".circle").hide();
  });


//9.

$(".toggleRedSquare").click(function() {
 doBoxBlink = setInterval(blink, 1000);

function blink() {
    $('.redSquare').toggle();
}


    });


});  // Close: $(document).ready(function() {
//https://jsfiddle.net/25oyk38f/18/

// %% [markdown]
// ## 69. JSON
//
// ### JSON structure and function.
// Explain what JSON is and how it is written.
//
// JSON is a format for data that can be used between servers and web applications like APIs. JSON is made up of two primary parts called keys and values.
//
// ### JSON data access.
// Explain how JSON is used to access data with strings, arrays, and objects.
//
// You would use the `variable.key` to get the strings and arrays, and `variable.key[index]` for objects.
//
// ### Traverse JSON.
// Explain how to traverse JSON and display content within an HTML page.
//
// You would loop over the array and output the results onto an HTML element.

// %% [markdown]
// ## 70. AJAX, Postman, and Google API
//
// ### AJAX
// Explain what AJAX is.
//
// Ajax allows web applications to dynamically load content from a server without doing a full page refresh.
//
// ### Postman
// Explain what Postman does.
//
// Postman is a Google Chrome App that makes it easy to test, develop and document APIs by allowing users to quickly put together both simple and complex HTTP requests.
//
//
// ### Google Maps API Description
// Explain what Google Maps API is and does.
//
// Google Maps API customizes Google maps with much greater detail.
//
// ### Google API Key
// Explain why a Google API key is needed.
//
// A key is needed for saving customized applications.
